# %% [markdown]
# <a href="https://colab.research.google.com/github/skiaadi/Conditional-Statements/blob/main/Conditional_Statements_EXP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 6 Conditional Statements
# #Aadi Havele
# #25070123001

# %%
#Check +ve or -ve
x = 10
if x>0:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
x = -10
if x>0:
    print("Positive")
elif x<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
#Even Odd
x = 10;
if x%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
#Largest
x = 10
y = 20
z = 30
if x>y and x>z:
    print(x)
elif x<y and y>z:
    print(y)
elif z>x and z>y:
    print(z)
# Out:
# 30

# %%
#Take marks of 5 subs
A = 90
B = 95
C = 80
D = 75
E = 90
avg = (A+B+C+D+E)/5
if avg>=90:
    print("Grade O")
elif avg>=80 and avg<90:
    print("Grade A+")
elif avg>=70 and avg<80:
    print("Grade A")
elif avg>=60 and avg<70:
  print("Grade B+")
elif avg>=50 and avg<60:
  print("Grade B")
elif avg>=40 and avg<50:
  print("pass")
# Out:
# Grade A+

# %%
#Q6 Check leap year

year = int(input("Enter a year"))
if(year%4==0 and year%100!=0) or (year%400==0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year2000
# Leap year

# %%
#7
date = input("Enter date in dd/mm/yyyy format ")
dd,mm,yyyy = date.split('/')
dd = int(dd)
mm = int(mm)
yyyy = int(yyyy)
print(date)

if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
    max1 = 31
elif(mm==4 or mm==6 or mm==9 or mm==11):
  max1 = 30
elif(mm==4):
  if(yyyy%400==0) or (yyyy%4==0 and yyyy%100!=0):
    max1 = 29
else:
  max1 = 28

if(mm<1 or mm>12):
  print("Date is invalid")
elif(dd<1 or dd>max1):
  print("Date is invalid")
elif(dd==max1 and mm!=12):
  dd=1
  mm=mm+1
  print("The incremented date is",dd,mm,yyyy)
elif(dd==31 and mm==12):
  dd=1
  mm=1
  yyyy=yyyy+1
  print("The incremented date is",dd,mm,yyyy)
# Out:
# Enter date in dd/mm/yyyy format 31/01/2026
# 31/01/2026
# The incremented date is 1 2 2026

# %%
#Q8
basic = float(input("Enter basic salary"))
if(basic<=10000):
  hra = 0.2*basic
  da = 0.8*basic
elif(basic<=20000):
  hra = 0.25*basic
  da = 0.9*basic
else:
  hra = 0.3*basic
  da = 0.95*basic

basic = basic+hra+da
print("Total Salary is ",basic)
# Out:
# Enter basic salary15000
# New Salary is  32250.0

# %%
date = input("Enter date in dd/mm/yyyy format ")
dd,mm,yyyy = date.split('/')
dd = int(dd)
mm = int(mm)
yyyy = int(yyyy)
print(date)

if dd>31 and mm>12:
  print("Date is invalid")
elif dd>29 and mm==02:
  print("Date is invalid")
elif dd>28 and mm==02 and yyyy%4!=0:
  print("Date is invalid")
elif dd>30 and (mm==4 or mm==6 or mm==9 or mm==11):
  print("Date is invalid")
else:
  print("Date is valid")

if dd<31 and mm==(1,3,5,7,8,10):
  dd=dd+1
elif dd<30 and mm==(4,6,9,11):
  dd=dd+1
elif dd==31 and mm==(1,3,5,7,8,10):
  dd=1
  mm=mm+1
elif dd==30 and mm==(4,6,9,11):
  dd=1
  mm=mm+1
elif dd==29 and mm==2 and yyyy%4==0:
  dd=1
  mm==mm+1
elif dd==28 and mm==2 and yyyy%4!=0:
  dd=1
  mm=mm+1
elif dd==31 and mm==12:
  dd=1
  mm=1
  yyyy=yyyy+1

print("The incremented date is",dd,mm,yyyy)
# Out:
# Enter date in dd/mm/yyyy format 06/03/2026
# 06/03/2026
# Date is valid
# The incremented date is 6 3 2026
